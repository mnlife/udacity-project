# %%
from keras.preprocessing import image
from keras.applications.inception_resnet_v2 import preprocess_input, decode_predictions
import numpy as np
import pickle
import matplotlib.pyplot as plt
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
X_train = np.zeros((25000, 224, 224 ,3))
y_train = np.zeros((25000)).astype(int)
for i in range(0, 20):
    X_train[1250*i: 1250*(i+1)], y_train[1250*i: 1250*(i+1)] = pickle.load(open("train_image_"+str(i), mode='rb'))
print("X_train shape:" + str(X_train.shape))
print("y_train shape:" + str(y_train.shape))
# Out:
# X_train shape:(25000, 224, 224, 3)
# y_train shape:(25000,)

# %%
plt.axis('off')
plt.imshow((X_train[24998]+1)/2)
plt.show()

# %%
X_test = np.zeros((12500, 224, 224 ,3))
for i in range(0, 10):
    X_test[1250*i: 1250*(i+1)] = pickle.load(open("test_image_"+str(i), mode='rb'))
    print(i)
print("X_test shape:" + str(X_test.shape))
# Out:
# X_test shape:(12500, 224, 224, 3)

# %%
plt.axis('off')
plt.imshow((X_test[45]+1)/2)
plt.show()
